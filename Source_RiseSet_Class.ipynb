# %%
# from helpers.ArrayCoordinate import MidPositions, LowPositions
# from helpers.TimeRange import TimeRange
from helpers.Observable import Observable

# %%
# target_dict = {'1646-50': "21:08:46.86357 -50:44:48.37", 
#                '1934-638': "19:39:25.026 -63:42:45.63", 
#                '1921-293': "19:24:51.055957 -29:14:30.121150",
#                'sdc335': "16:30:58.638 -48:43:51.70"}

target_dict = {'1646-50': "21:08:46.86357 -50:44:48.37"}

test_Obs = Observable('Mid',target_dict,'2023-05-17 16:02:00', 6.0, 'm')
print(test_Obs.provide_plot())
# Out:
# Array:Mid
# Using only SKA dishes
# 6.0 m
# <SkyCoord (ICRS): (ra, dec) in deg
#     (317.19526487, -50.74676944)>
# <SkyCoord (AltAz: obstime=['2023-05-17 16:02:00.000' '2023-05-17 16:05:00.000'
#  '2023-05-17 16:08:00.000'], location=(5109271.36619669, 2006687.36897168, -3239042.17785115) m, pressure=0.0 hPa, temperature=0.0 deg_C, relative_humidity=0.0, obswl=1.0 micron): (az, alt) in deg
#     [(180.36187034, -8.63611227), (179.87956002, -8.63747715),
#      (179.39726711, -8.63339934)]>
# None
